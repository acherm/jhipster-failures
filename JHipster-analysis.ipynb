# %%
import pandas as pd

jh = pd.read_csv('jhipster.csv', sep=';')
jh
# Out:
#                   Id  JHipsterRegister  Docker  applicationType  \
# 0      1517153311464     jhipster10186   false       "monolith"
# 1      1517153592569     jhipster10187   false       "monolith"
# 2      1517153833773     jhipster10188   false        "gateway"
# 3      1517154138781     jhipster10189   false       "monolith"
# 4      1517154412063     jhipster10190   false       "monolith"
# ...              ...               ...     ...              ...
# 21184             Id  JHipsterRegister  Docker  applicationType
# 21185  1517152619853     jhipster92821   false       "monolith"
# 21186  1517152942459     jhipster92822   false       "monolith"
# 21187  1517153196870     jhipster92823   false        "gateway"
# 21188  1517153576855     jhipster92824   false   "microservice"
#
#        serviceDiscoveryType  authenticationType  hibernateCache  \
# 0                     false            "oauth2"     "hazelcast"
# 1                     false               "jwt"            "no"
# ...

# %%
jh2 = pd.read_csv('JHipster-gp.csv')
jh2
# Out:
#       JHipsterRegister  Docker applicationType authenticationType  \
# 0            jhipster1    True      "monolith"          "session"
# 1            jhipster1   False      "monolith"          "session"
# 2            jhipster2    True      "monolith"              "jwt"
# 3            jhipster2   False      "monolith"              "jwt"
# 4            jhipster3    True      "monolith"              "jwt"
# ...                ...     ...             ...                ...
# 26251    jhipster13126   False      "monolith"          "session"
# 26252    jhipster13127    True      "monolith"           "oauth2"
# 26253    jhipster13127   False      "monolith"           "oauth2"
# 26254    jhipster13128    True      "monolith"          "session"
# 26255    jhipster13128   False      "monolith"          "session"
#
#       hibernateCache clusteredHttpSession           websocket databaseType  \
# 0               "no"          "hazelcast"  "spring-websocket"        "sql"
# ...

# %%
logs_build = jh2.query("Build == 'KO' | Compile == 'KO'")["Log-Build"]

ilog = 0
for logs in logs_build.unique():
    ilog = ilog + 1
    if (ilog == 100):
        break
    print(logs)
    print
# Out:
# Exception encountered during context initialization - cancelling refresh attempt: org.springframework.beans.factory.BeanCreationException: Error creating bean with name 'liquibase' defined in class path resource [io/variability/jhipster/config/DatabaseConfiguration.class]: Invocation of init method failed; nested exception is java.lang.RuntimeException: Failed to get driver instance for jdbcUrl=jdbc:mariadb://mariadb:3306/jhipster
#
# Exception: Error creating bean with name 'org.springframework.cache.annotation.ProxyCachingConfiguration': Initialization of bean failed; nested exception is org.springframework.beans.factory.NoSuchBeanDefinitionException: No bean named 'org.springframework.context.annotation.ConfigurationClassPostProcessor.importRegistry' is defined)
#
# ...

# %%
9376 / len(jh2)
# Out:
# 0.3570993296770262

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(jh2.drop(columns=['Build', 'Compile', 'Log-Build', 'Log-Compile', 'JHipsterRegister']), jh2['Build'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f2614854bef4> in <module>
#       2
#       3 clf = tree.DecisionTreeClassifier()
# ----> 4 clf = clf.fit(jh2.drop(columns=['Build', 'Compile', 'Log-Build', 'Log-Compile', 'JHipsterRegister']), jh2['Build'])
#
# /usr/local/lib64/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# /usr/local/lib64/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
# ...

# %%
from sklearn import preprocessing
import numpy as np 

le = preprocessing.LabelEncoder()

# le.fit_transform(jh2["applicationType"])
pd.get_dummies(jh2)

# preprocessing.OneHotEncoder().fit_transform(jh2)
# Out:
#        Docker  enableTranslation  JHipsterRegister_jhipster1  \
# 0        True              False                           1
# 1       False              False                           1
# 2        True               True                           0
# 3       False               True                           0
# 4        True               True                           0
# ...       ...                ...                         ...
# 26251   False               True                           0
# 26252    True               True                           0
# 26253   False               True                           0
# 26254    True               True                           0
# 26255   False               True                           0
#
#        JHipsterRegister_jhipster10  JHipsterRegister_jhipster100  \
# 0                                0                             0
# 1                                0                             0
# ...

# %%
jh2["testFrameworks"].unique()
# Out:
# array(['["cucumber","protractor","gatling"]',
#        '["gatling","cucumber","protractor"]',
#        '["cucumber","gatling","protractor"]',
#        '["gatling","protractor","cucumber"]',
#        '["protractor","gatling","cucumber"]',
#        '["protractor","cucumber","gatling"]', '["cucumber","gatling"]',
#        '["gatling","cucumber"]'], dtype=object)
